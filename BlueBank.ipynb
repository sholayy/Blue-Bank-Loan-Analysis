# %%
import pandas as pd 
import numpy as np 
import json 
import matplotlib.pyplot as plt

# %%
# read json data
json_file = open("loan_data_json.json")
data = json.load(json_file)

# %%
loandata= pd.DataFrame(data)

# %%
loandata.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
loandata.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
loandata['dti'].describe()
# Out:
# count    9578.000000
# mean       12.606679
# std         6.883970
# min         0.000000
# 25%         7.212500
# 50%        12.665000
# 75%        17.950000
# max        29.960000
# Name: dti, dtype: float64

# %%
# using exp to get the annual income
loandata['annualincome'] = np.exp(loandata['log.annual.inc'])
loandata.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid  annualincome
# ...

# %%
def fico_range(x):
    if x >=300 and x < 400:
        return "Very poor"
    elif x >=400 and x < 600:
        return "Poor"
    elif x >=600 and x < 660:
        return "Fair"
    elif x >=660 and x < 780:
        return "Good"
    elif x >= 780:
        return "Excellent"
    else:
        return "Unknown"

# %%
loandata['ficocat'] = loandata['fico'].apply(fico_range)

# %%
loandata['Int Rate Type'] = loandata['int.rate'].apply(lambda x: 'High' if x > 0.12 else 'Low')

# %%
loandata.head()
# Out:
#    credit_policy             purpose  int_rate  installment  log_annual_inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days_with_cr_line  revol_bal  revol_util  inq_last_6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
# ...

# %%
catplot = loandata.groupby(['ficocat']).size()
purposecount = loandata.groupby(['purpose']).size()
purposecount
# Out:
# purpose
# all_other             2331
# credit_card           1262
# debt_consolidation    3957
# educational            343
# home_improvement       629
# major_purchase         437
# small_business         619
# dtype: int64

# %%
# plot
catplot.plot.bar(color='green',width=0.1)
plt.show()

# %%
loandata.columns = loandata.columns.str.replace('.','_')
# Out:
# /Users/Sola/.virtualenvs/prep-venv/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
loandata.head()
# Out:
#    credit_policy             purpose  int_rate  installment  log_annual_inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days_with_cr_line  revol_bal  revol_util  inq_last_6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
# ...

# %%
loandata.to_csv('loan_cleaned.csv',index=True)
